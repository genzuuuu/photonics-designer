# %%
pip install torch
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 536.2/536.2 kB 3.8 MB/s eta 0:00:0000:0100:01
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 59.7/59.7 MB 38.3 MB/s eta 0:00:0000:0100:01
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 5.7/5.7 MB 40.0 MB/s eta 0:00:00a 0:00:01
# ...
#
# [notice] A new release of pip is available: 23.3.2 -> 24.0
# [notice] To update, run: pip3 install --upgrade pip
# Note: you may need to restart the kernel to use updated packages.

# %%
from llama_index.llms.llama_api import LlamaAPI
import os
from llama_index import (
    SimpleDirectoryReader,
    ServiceContext,
    KnowledgeGraphIndex,
    VectorStoreIndex,
)
from llama_index.llms import Replicate
from llama_index.graph_stores import SimpleGraphStore
from llama_index.llms import OpenAI
from llama_index.llms.llama_api import LlamaAPI

os.environ["REPLICATE_API_TOKEN"] = "r8_ZZrxF6TTsXEA56isDAJ1QaipkP9KoYk0Qfkbr"
from llama_index.prompts import PromptTemplate
from llama_index.llms import Replicate


llm = Replicate(
    model="meta/llama-2-70b-chat:2796ee9483c3fd7aa2e171d38f4ca12251a30609463dcfd4cd76703f22e96cdf",
    is_chat_model=True,
    additional_kwargs={"max_new_tokens": 512}
)

service_context = ServiceContext.from_defaults(llm=llm, embed_model="local:BAAI/bge-small-en-v1.5")

from llama_index.storage.storage_context import StorageContext

graph_store = SimpleGraphStore()
storage_context = StorageContext.from_defaults(graph_store=graph_store)

# %%
# !unzip gdsfactory-main.zip
# Out:
# Archive:  gdsfactory-main.zip
# 6de1af1a5f26516eb05f231b1da6a5cf6e199b31
# replace gdsfactory-main/.all-contributorsrc? [y]es, [n]o, [A]ll, [N]one, [r]ename: ^C

# %%
from llama_index import SimpleDirectoryReader

# load documents
documents = SimpleDirectoryReader("gdsfactory-main").load_data()

# %%
os.environ["OPENAI_API_KEY"] = "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"
# create the blank knowledge graph (index)
index_from_scratch_9 = VectorStoreIndex(
    [],
    service_context = service_context,
)
index_from_scratch_9 = VectorStoreIndex.from_documents(documents)

# %%
query_engine = index_from_scratch_9.as_query_engine(
    include_text=False, response_mode="tree_summarize"
)
# response = query_engine.query(
#     "please refer to the context restrictedly for all the code you generates. Create the compenent c via 'gf.Component()', then draw two MZI into the c mimic this command 'mzi1 = c << gf.components.mzi()'. move the second one in x direction for 200. Then connect them together by using 'mzi2.connect('o1',mzi1.ports['o2'])'. Please write the code for that and only use the function available in the gdsfactory.",
# )

response = query_engine.query(
    "Please refer to the context restrictedly for all the code you generates and not trump up anything that not in the context. Then create "
    
)

# %%
from IPython.display import Markdown, display

# display the response
display(Markdown(f"<b>{response}</b>"))
# Out:
# <b>```python
# import gdsfactory as gf
#
# c = gf.Component()
# mzi1 = c << gf.components.mzi_arms()
# mzi2 = c << gf.components.mzi_arms()
# mzi2.move((200, 0))
# mzi2.connect('o1', mzi1.ports['o2'])
# ```</b>

# %%
# My OpenAI Key
import os
#os.environ["OPENAI_API_KEY"] = "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"
os.environ["OPENAI_API_KEY"] = "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"

import logging
import sys

logging.basicConfig(stream=sys.stdout, level=logging.INFO)

from llama_index.llms.llama_api import LlamaAPI
from llama_index import download_loader
from llama_index import (
        SimpleDirectoryReader,
        ServiceContext,
        KnowledgeGraphIndex,
)
from llama_index.llms import Replicate
from llama_index.graph_stores import SimpleGraphStore
from llama_index.llms import OpenAI
from llama_index.llms.llama_api import LlamaAPI
from IPython.display import Markdown, display


llm = OpenAI(temperature=0, model='gpt-3.5-turbo')
service_context = ServiceContext.from_defaults(llm=llm, chunk_size=512)

# create the index using the provided documents
from llama_index.storage.storage_context import StorageContext

graph_store = SimpleGraphStore()
storage_context = StorageContext.from_defaults(graph_store=graph_store)

new_index = KnowledgeGraphIndex.from_documents(
    documents,
    max_triplets_per_chunk=2,
    service_context=service_context,
    include_embeddings=True,
)
# Out:
# INFO:httpx:HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# INFO:httpx:HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# INFO:httpx:HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# INFO:httpx:HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# INFO:httpx:HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# INFO:httpx:HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# INFO:httpx:HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# INFO:httpx:HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# INFO:httpx:HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# INFO:httpx:HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# INFO:httpx:HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# ...

# %%
from pyvis.network import Network

g = new_index.get_networkx_graph()
net = Network(notebook=True, cdn_resources="in_line",directed=True)
net.from_nx(g)
net.show("gdsfactory-knowledge-graph.html")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[26], line 3
#       1 from pyvis.network import Network
# ----> 3 g = new_index.get_networkx_graph()
#       4 net = Network(notebook=True, cdn_resources="in_line",directed=True)
#       5 net.from_nx(g)
#
# NameError: name 'new_index' is not defined
